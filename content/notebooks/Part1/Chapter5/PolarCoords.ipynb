# %% [markdown]
# <a href="https://colab.research.google.com/github/jjcrofts77/Advanced-Calculus-MATH20471/blob/main/content/notebooks/Part1/Chapter5/PolarCoords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5.2 BVP in polar coordinates
#
# Next, let us consider separable solutions of Laplace's equation of the form $T(r,\theta)=F(r)G(\theta)$. Substitution into {eq}`LaplaceCh5Polar` gives
#
# $$
#  F''(r)G(\theta)+\frac{1}{r}F'(r)G(\theta)+\frac{1}{r^2}F(r)G''(\theta)=0.
# $$
#
# Hence
#
# $$
#  \frac{r^2F''(r)+rF'(r)}{F(r)} + \frac{G''(\theta)}{G(\theta)} = 0,
# $$
#
# and there is a constant $\lambda$ such that
#
# $$
#  r^2F''(r)+rF'(r)=\lambda F(r),
# $$ (Fpolar)
#
# $$
#  G''(\theta) = -\lambda G(\theta).
# $$ (Gpolar)
#
# The function $G(\theta)$ must be periodic with period $2\pi$ so that $G(\theta+2\pi)=G(\theta)$, and this is possible only if $\lambda=n^2$, where $n$ is an integer. If $n=0$, the only solution of {eq}`Gpolar` which are periodic are $G(\theta)\equiv \text{constant}$. If $n\neq 0$ the periodic solutions are arbitrary linear combinations of $\cos(n\theta)$ and $\sin(n\theta)$. When $n=0$ solutions of {eq}`Fpolar` are of the form $F(r)=A+B\log{r}$. When $n\neq 0$, equation {eq}`Fpolar` is of Euler's type and $F(r)$ is a linear combination of $r^n$ and $r^{-n}$. Thus there are separable solutions of Laplace's equation of the forms
#
# $$
#  T(r)=A+B\log(r),
# $$
#
# and
#
# $$
# T(r,\theta) = \left(Ar^n+Br^{-n}\right)\left[C\cos(n\theta)+D\sin(n\theta)\right],
# $$
#
# where $n$ is a positive integer and $A, B, C, D$ are arbitrary constants. The solutions $\log{r}, r^{-n}\cos(n\theta), r^{-n}\sin(n\theta)$ are not defined at $r=0$ and so are not admissible if the origin belongs to the domain in which $T$ is defined.
#
# \noindent {\bf Example 5.1} Find $T$ so as to satisfy Laplace's equation in the annulus $a<r<b$ and the boundary conditions
# \begin{equation}
#  T=T_0 \text{ on } r=a, \quad T=T_1 \text{ on } r=b,
# \end{equation}
# where $T_0$ and $T_1$ are constants.
#
# By inspection, $T=A+B\log(r)$, where $A$ and $B$ must satisfy
#
# $$
# A+B\log(a)=T_0, \quad A+B\log(b)=T_1.
# $$
#
# Then
#
# $$
# A=\frac{T_0\log(b)-T_1\log(a)}{\log(b/a)},\quad B=\frac{T_1-T_0}{\log(b/a)},
# $$
#
# and
#
# $$
#  T(r,\theta) = \frac{T_0\log(b)-T_1\log(a)}{\log(b/a)}+\frac{T_1-T_0}{\log(b/a)}\log(r).
# $$
#
# <br>
#
# **Example 5.2** A conductor occupies the region $r\leq a$ and the temperature satisfies the boundary condition $T(a,\theta)=\sin^3(\theta)$. Find $T(r,\theta)$ in $r<a$.
#
# Note that
#
# $$
# \sin^3(\theta) = \frac{3}{4}\sin(\theta)-\frac{1}{4}\sin(3\theta).
# $$
#
# Hence
#
# $$
# T = \frac{3}{4}\left(\frac{r}{a}\right)\sin(\theta)-\frac{1}{4}\left(\frac{r}{a}\right)^3\sin(3\theta).
# $$
#
# ## Application of Fourier Series (optional)
#
# We wish to find $T$ so as to satisfy Laplace's equation in the disc $0\leq r<a$ and the boundary condition $T=f(\theta)$ on $r=a, (0\leq \theta\leq 2\pi)$, where $f$ is a prescribed function. Here the solution is of the form
#
# $$
#  T(r,\theta) = A + \sum_{n=1}^\infty r^n\left[C_n\cos(n\theta)+D_n\sin(n\theta)\right],
# $$
#
# and the boundary condition gives
#
# $$
#  A + \sum_{n=1}^\infty a^n\left[C_n\cos(n\theta)+D_n\sin(n\theta)\right] = f(\theta), \quad 0\leq\theta\leq 2\pi.
# $$
#
# Thus
#
# $$
# A&=\frac{1}{2\pi}\int_0^{2\pi}f(\theta)\mathrm{d}\theta,\\
# C_n &=\frac{1}{\pi a^n}\int_0^{2\pi}f(\theta)\cos(n\theta)\mathrm{d}\theta\\
# D_N&=\frac{1}{\pi a^n}\int_0^{2\pi}f(\theta)\sin(n\theta)\mathrm{d}\theta.
# $$
#
# <br>
#
# **Example 5.3** Find $T(r,\theta)$ so as to satisfy Laplace's equation in the disc $r<a$ and the boundary condition
#
# $$
#  T(a,\theta) = |\sin(\theta)|,\quad 0\leq \theta\leq 2\pi.
# $$
#
# The solution is
#
# $$
#  T(r,\theta) = A+\sum_{n=1}^\infty r^n\left[C_n\cos(n\theta)+D_n\sin(n\theta)\right],
# $$
#
# where
#
# $$
# A &=\frac{1}{2\pi}\int_0^{2\pi}|\sin(\theta)|\mathrm{d}\theta=\frac{1}{2\pi}\left[\int_0^\pi\sin\theta\mathrm{d}\theta - \int_\pi^{2\pi}\sin\theta\mathrm{d}\theta\right]=\frac{2}{\pi},\\
# C_n&=\frac{1}{\pi a^n}\int_0^{2\pi}|\sin\theta|\cos(n\theta)\mathrm{d}\theta=\begin{cases}0&n\text{ odd},\\-4/(\pi a^n(n^2-1))&n \text{ even },\end{cases}\\
# D_n&= \frac{1}{\pi a^n}\int_0^{2\pi}|\sin\theta|\sin(n\theta)\mathrm{d}\theta=0,
# $$
#
# and so
#
# $$
# T(r,\theta) = \frac{2}{\pi}-\frac{4}{\pi}\sum_{n=1}^\infty\left(\frac{r}{a}\right)^{2n}\frac{\cos(2n\theta)}{4n^2-1}.
# $$
